# %%
# !pip install selenium. # Instalar la bibliote de selenium
pip install webdriver-manager # instalar una biblioteca para controlar el navegador
pip install beautifulsoup4 # instalar la biblioteca de bs

# %%
pip install webdriver-manager # instalar una biblioteca para controlar el navegador
# Out:
# ...
#
# [notice] A new release of pip is available: 25.2 -> 26.1.1
# [notice] To update, run: /usr/local/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importar librerías para tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd  

# Importar librerías para web scraping y manipulación de datos
# -----------------------------------------------------------------------
from bs4 import BeautifulSoup
import requests

# Importar librerías para automatización de navegadores web con Selenium
# -----------------------------------------------------------------------
from selenium import webdriver  # Selenium es una herramienta para automatizar la interacción con navegadores web.
from webdriver_manager.chrome import ChromeDriverManager  # ChromeDriverManager gestiona la instalación del controlador de Chrome.
from selenium.webdriver.common.keys import Keys  # Keys es útil para simular eventos de teclado en Selenium.
from selenium.webdriver.support.ui import Select  # Select se utiliza para interactuar con elementos <select> en páginas web.

# Importar librerías para pausar la ejecución
# -----------------------------------------------------------------------
from time import sleep  # Sleep se utiliza para pausar la ejecución del programa por un número de segundos.

# Configuraciones
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None)  # Establece una opción de Pandas para mostrar todas las columnas de un DataFrame.

# %%
driver = webdriver.Chrome()
driver.get("https://adalab.es/")
driver.maximize_window()
sleep(1)
driver.find_element("css selector", "#wt-cli-accept-all-btn").click()
sleep(1)
driver.save_screenshot("adalab.png")
sleep(1)
driver.find_element("link text", "BLOG").click()
sleep(3)
driver.close()

# %%
# Funciones:

driver.maximize_window #para hacer más grande la ventana
driver.get() # para pasarle la url
driver.find_element() #con el tipo de elemento y el titulo
.click() #para hacer clic en algo
driver.close() #cerramos conexion
sleep(5) #para que espere 5 segundos antes de hacer la siguiente accion
driver.send_keys("texto") #escribe texto
driver.quit() #cierra todas las ventanas del navegador
driver.back() #Navega hacia atrás, como el botón de flecha "atrás"
driver.forward() #Lo mismo, pero hacia delante
driver.refresh() #refresca la página

# %%
driver = webdriver.Chrome()
driver.get("https://beta.adalab.es/online_supermarket/")
driver.maximize_window()
driver.find_element("css selector", "body > div.__variable_a6519f > div > div > button.CookieConsent_acceptButton__Mb_bR.CookieConsent_acceptAllButton__yhaaI").click()
sleep(3)
driver.find_element("css selector", ".HamburgerMenu_hamburgerMenu__fcrHL").click()
sleep(3)
link = driver.find_element("xpath", "/html/body/div/header/div/div[2]/ul/li[2]/a")
link.click()
sleep(5)
diccionario_fruta = {"nombres": [], "precios": []}
for i in range (1, 3):
                sleep(5)
                nombre = driver.find_element("css selector", f"body > main > div.ProductsListSection_container__d5XJ3 > a:nth-child({i}) > div > div.ProductCard_details__ElEDC > h3").text
                sleep(5) 
                diccionario_fruta["nombres"].append(nombre)
                sleep(5)
                precio = driver.find_element("css selector", f"body > main > div.ProductsListSection_container__d5XJ3 > a:nth-child({i}) > div > div.ProductCard_details__ElEDC > p > span:nth-child({i})").text
                sleep(5)
                diccionario_fruta["precios"].append(precio)
diccionario_fruta

# cerramos el navegador
driver.close()

# %%
body > main > div.ProductsListSection_container__d5XJ3 > a:nth-child(1) > div > div.ProductCard_details__ElEDC > h3
body > main > div.ProductsListSection_container__d5XJ3 > a:nth-child(2) > div > div.ProductCard_details__ElEDC > h3

# %%
diccionario_fruta
# Out:
# {'nombres': ['Manzanas Golden, bandeja 1 Kg aprox.',
#   'Plátanos de Canarias, mano 1 Kg aprox.'],
#  'precios': ['2.49 €', '2.89 €/kg']}

# %%
df = pd.DataFrame(diccionario_fruta)
df
# Out:
#                                   nombres    precios
# 0    Manzanas Golden, bandeja 1 Kg aprox.     2.49 €
# 1  Plátanos de Canarias, mano 1 Kg aprox.  2.89 €/kg
