# %% [markdown]
# ### Listas --> Datos heterogéneos, acepta repetidos, elementos mutables, accesible por índice

# %%
nombre1="Manuela"
nombre2="Cecilia"
nombre3="Teresa"
nombre4="Rosa"

# %%
## lista 
lista_nombres=["Manuela", "Cecilia", "Teresa"]
lista_edades= [20, 35, 18]
lista_alumna=["Angeles", 20, "Madrid", True, "Trabajo en Remoto", "Madrid"] ## datos heterogeneos, valores repetidos

# %%
lista_nombres
# Out:
# ['Manuela', 'Cecilia', 'Teresa']

# %%
#añadir un nuevo elemento a la lista
lista_nombres.append("Bea")

# %%
## insertar
#lista_nombres.insert(indice, "lo que quiero insertar")
lista_nombres.insert(0, "Ani")

# %%
lista_nombres.insert(1, "Alexandra")

# %%
lista_edades.insert(0, 24)

# %%
# extend 
lista_nombres.extend(lista_edades)

# %%
print(lista_nombres)
# Out:
# ['Alexandra', 'Manuela', 'Cecilia', 'Bea', 20, 35, 18]

# %%
lista_edades
# Out:
# [24, 20, 35, 18]

# %%
## elimina el primer valor que se encuentre
lista_nombres.remove("Bea")

# %%
lista_nombres.remove("Yanelis")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 lista_nombres.remove("Yanelis")
#
# ValueError: list.remove(x): x not in list

# %%
## pop: 
lista_nombres.pop(3)
# Out:
# 'Teresa'

# %%
## calcula el tamaño de la lista
len(lista_nombres)
# Out:
# 6

# %%
lista_nombres.append("Yanelis")

# %%
lista_nombres=["Manuela", "Cecilia", "Teresa"]

# %%
lista_nombres.remove("Manuela")

# %%
lista_nombres
# Out:
# ['Cecilia', 'Teresa']

# %%
lista_nombres.pop(0)
# Out:
# 'Cecilia'

# %%
numeros = 31, 35, 67, 89, 76

# %%
numeros
# Out:
# (31, 35, 67, 89, 76)

# %%
lista_numeros = list(numeros)

# %%
lista_numeros
# Out:
# [31, 35, 67, 89, 76]

# %%
lista_numeros.sort()

# %% [markdown]
# Funciones:
#
# - .append() --> añadir nuevo elemento a la lista (solo uno)
# - .insert() --> añadir elemento, pero diciéndole primero en qué índice lo quiero
# - .extend() --> añadir varios elementos a la lista, entre corchetes
# - .remove() --> quita un elemento en concreto
# - .pop() --> quita el último elemento de la lista o el de una ubicación en concreto
# - .reverse() --> le da la vuelta a esa lista
# - .sort() --> ordena la lista
# - .clear() --> vacía la lista
# - .count() --> cuenta cuántas veces aparece en la lista el elemento que pongamos entre paréntesis ej: lista_compra.count("fresas")
# - .index() --> nos dice el índice del valor que le pasemos
# - len() --> nos dice cuántos elementos tiene la lista
# - min()
# - max()
# - copy() --> crea una copia para no sobreescribir la primera

# %%
max(lista_numeros)
# Out:
# 89

# %%
## cuantas veces aparece
lista_numeros.count(67)
# Out:
# 1

# %%
## en que posiscin está
lista_numeros.index(67)
# Out:
# 2

# %%
lista_numeros.reverse()

# %%
lista_numeros
# Out:
# [89, 76, 67, 35, 31]

# %%
lista_nombres
# Out:
# ['Manuela', 'Cecilia', 'Teresa']

# %%
min(lista_nombres)
# Out:
# 'Cecilia'

# %%
#De la siguiente lista, elimina un país concreto, añade otro en una ubicación concreta, dale la vuelta, pide a la usuaria que introduzca
# un país y añádelo a la lista,
# ordénala por orden alfabético y cuenta cuántos países hay
paises = ["España", "Italia", "Bélgica", "Suiza", "Portugal"]

# %%
len(paises)
# Out:
# 5

# %%
paises.remove("Italia")

# %%
# añade otro en una ubicación concreta
paises.insert(1, "Suecia")

# %%
#dale la vuelta
paises.reverse()

# %%
# pide a la usuaria que introduzca un país y añádelo a la lista
nuevo_pais = input("Dime el pais que quieres introducir")
paises.append(nuevo_pais)

# %%
# comprobacion
print(len(paises))
print(paises)
# Out:
# 9
# ['', 'Bélgica', 'España', 'Portugal', 'Suecia', 'Suiza', 'brasil', 'china', 'japon']

# %%
paises.sort()

# %% [markdown]
# # Tuplas --> Datos heterogéneos, acepta repetidos, inmutables, accesible por índice
#
# - Tuplas = ()
# - Heterogénea (3,4,"María, False)
# - Inmutables: no se pueden añadir, eliminar o cambiar sus elementos
# - Para cambiar, se puede pasar a lista
# - Puede contener elementos MUTABLES
# - Convertir en tupla: tuple()
# - in y not in
#
# Funciones:
#
# - .count()
# - .index()
# - len()
# - min()
# - max()

# %%
## Tuplas: son inmutables 
tupla = (30, "Lluvia", "Sevilla", [4, 5, 7])

# %%
tupla[0]
# Out:
# 30

# %%
lista_nombres[0]
# Out:
# 'Manuela'

# %%
tupla[3]
# Out:
# [4, 5, 7]

# %%
tupla[3][1]
# Out:
# 5

# %%
# convertir una tupla en unlista
lista = list(tupla)

# %%
nueva_tupla = tuple(lista_edades)

# %%
nueva_tupla

# %%
## Acceder a los valores de una lista p una tuple
lista_nombres
# Out:
# ['Manuela', 'Ceci', 'Teresa']

# %%
lista_nombres[1]="Ceci"

# %%
tupla[1]
# Out:
# 'Lluvia'

# %%
## añadir valores: insert, append
## modificar valores solo en lista: accedo por la posición
# las posiciones empiezan a contar en cero
# metodos: remove, pop, len, count......
# lista: modificabl
# tupla: valores inmutables, no se puede modificar
