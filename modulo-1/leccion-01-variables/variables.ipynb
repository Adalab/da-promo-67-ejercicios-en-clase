# %% [markdown]
# # Leccion 1 : Variables

# %% [markdown]
# ## Declaracion de variables

# %%
# nombre_variable = valor

# esta es la promo 67
promo = 67
# y su profe vive en valladolid
ciudad= "valladolid"
ciudad_nacimiento = "valladolid"

# %%
print(promo)
# Out:
# 67

# %%
print(ciudad)
# Out:
# valladolid

# %% [markdown]
# # Tipo s de Dats

# %%
# Numericos
edad = 29 # valor entero
altura = 1.58 # valor decimal

# %%
# cadenas de texto, caracterres : string
nombre = 'Ana Sabina'
correo = "ana@gmail.com"

# %%
correo = ana@gmail.com
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 correo = ana@gmail.com
#
# NameError: name 'ana' is not defined

# %%
# booleanos: true o false
matriculada= False ## no está matriculada
mayor_de_edad= True ## es mayor de edad

# %%
codigo_postal = "28000"
edad_1="20"
edad_2= "23"

# %%
type(edad_1)
# Out:
# str

# %%
# cambiar tipo de datos
edad_entera =int(edad_1)

# %%
type(edad_entera)
# Out:
# int

# %%
edad_entera
# Out:
# 20

# %%
nombre = "Cris"
edad = 25
ciudad = "Madrid"

# %%
# castear = convertir 
str(edad)

# %%
int(nombre)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 int(nombre)
#
# ValueError: invalid literal for int() with base 10: 'Cris'

# %%
print("Hola soy ", nombre ,  "y tengo " , str(edad) , "años")
# Out:
# Hola soy  Cris y tengo  25 años

# %%
nombre= "Ani"
nombre= "Rocio"
nombre="Angeles"

# %%
print(nombre)
# Out:
# Angeles

# %%
anio_1= 2020
anio_2 = 2021

# %%
print(anio_1+anio_2)
# Out:
# 4041

# %%
print("Los años son", anio_1, anio_2 ) 
## fstring
# Out:
# Los años son 2020 2021

# %%
numero1 = 20
numero2 = 30

# %%
print(numero1+numero2)
print(numero1-numero2)
print(numero1/numero2)
print(numero1*numero2)
print(numero1**numero2)
# Out:
# 50
# -10
# 0.6666666666666666
# 600
# 1073741824000000000000000000000000000000

# %%
type(numero1)
# Out:
# int

# %%
isinstance
# Out:
# False

# %% [markdown]
# ## Metodos de strings
#
# - .upper()
# - .lower()
# - .title()
# - .capitalize()
# - .swapcase()
# - .strip()
# - .split()
# - .replace()
# - len()
# - .find()
# - .count()

# %%
nombre = " Bea,san,josé "

# %%
nombre.lower()
# Out:
# 'cris'

# %%
nombre.upper()
# Out:
# 'CRIS'

# %%
nombre.title()
# Out:
# 'Bea San'

# %%
nombre.capitalize()
# Out:
# 'Bea san'

# %%
nombre.replace("Bea", "Beatriz")
# Out:
# 'Beatriz san'

# %%
nombre.strip()
# Out:
# 'Bea san'

# %%
nombre.split(",")
# Out:
# [' Bea', 'san', 'josé ']

# %%
# input: para obtener valores del usuario 
nombre_usuario = input("Dime tu nombre")
print("Hola", nombre_usuario)
# Out:
# Hola Alex

# %%
nombre_usuario
# Out:
# 'Alex'

# %%
# nomenclatura 
nombre_ciudad = "Valladolid"
persona_nombre = "Teresa"

user_age = 25
